# %% [markdown]
# # sample generator for embedded questions
# This notebook is for creating the random sample .txt files for the experiment.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
#  # Contents
#  1. [Constrain the data set to stimuli set](#Constrain-the-dataset-to-stimuli-set)
#  2. [Figuring out the distribution of factors per list](#Figuring-out-the-distribution-of-factors-per-list)
#  3. [Figure out how to collapse the matrix verb columns](#Figure-out-how-to-collapse-the-matrix-verb-columns)
#  4. [Add in the paraphrases](#Add-in-the-paraphrases)
#  5. [Split EntireSentence on Question](#Split-EntireSentence-on-Question)
#  6. [Controls](#Controls)
#  7. [Balancing factors](#Balancing-factors)
#      1. [Modal Balancing](#Modal-Balancing)
#      2. [Wh Balancing](#Wh-Balancing)
#          1. [Who](#Who)
#          2. [What](#What)
#          3. [Where](#Where)
#          4. [When](#When)
#          5. [How](#How)
#          6. [Why](#Why)
#  8. [Generating-random-samples](#Generating-random-samples)
#      1. [First Iteration](#First-Iteration)
#      2. [Second Iteration](#Second-Itreation)
#      3. [Third Iteration](#Third-Iteration)
#      4. [Fourth Iteration](#Fourth-Iteration)
#      5. [Fifth Iteration](#Fifth-Iteration)
#      6. [Sixth Iteration](#Sixth-Iteration)
#      7. [Final Set](#Final-Set)
#  9. [Pilot Samples](#Pilot-Samples)

# %%
# import the database file from the TGrep2 searching
df = pd.read_csv("../results/swbd.tab", sep='\t', engine='python')

# %%
df.head()
# Out:
#   Item_ID                                           Sentence HaveNeedTo  \
# 0    3:43  uh, first, um, i need *-1 to know, uh, how do ...         no
# 1   17:77  and, uh, we were, i was fortunate in that i wa...         no
# 2   21:45  so, i was very comfortable, you know, in *-1 d...        yes
# 3   23:31  well, i had an occasion for my mother-in-law w...        yes
# 4   96:22  i mean, for somebody who *t*-1 is, you know, f...         no
#
#   Finite ModalPresent QuestionType EmbeddedSQ DegreeQ SubjectAuxInv WhAll  \
# 0    yes           no     embedded        yes      no           yes   NaN
# 1    yes           no      subject        NaN      no           NaN   NaN
# 2    yes           no   embadjunct        NaN      no           NaN   NaN
# 3    NaN          yes     relative        NaN      no           NaN   NaN
# 4    yes           no     relative        NaN      no           NaN   NaN
#
#    ... FullWhPhrase                                   JustMatrixClause  \
# ...

# %%
# This makes the display show more info
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
df.pivot_table(index=['QuestionType'], values="Question", aggfunc=len).groupby(["QuestionType"]).Question.transform(lambda x: x/len(df)).reset_index()
# Out:
#   QuestionType  Question
# 0      adjunct  0.075203
# 1        cleft  0.064712
# 2   embadjunct  0.236886
# 3     embedded  0.160800
# 4     fragment  0.067654
# 5     relative  0.133150
# 6         root  0.124424
# 7      subject  0.137072

# %% [markdown]
# # Constrain the dataset to stimuli set
# for experimental mock-up
#
# First we have to remove the questions that we don;t want to include:
# 1. embedded questions only
# 2. no degree questions
# 3. no identity questions
# 4. generally only monomorphemic wh-phrases
# 5. only who-, what-, where-, when-, how-, and why-questions

# %%
critical = df[(df['QuestionType'] == 'embedded') # only embedded questions
              & 
              (df['Finite'] == 'no' )] # infinitival clauses

# %%
len(critical)
# Out:
# 135

# %%
7*30
# Out:
# 210

# %% [markdown]
# ### Figuring out how many lists
#
# 135/20
#
# 6 lists of 20, 1 of 15
#
# 15 how / 6list
# 4 whats / 6 lists
# then random sample 1 item from the remainders
#
# last list is whatever's left over (total 15 items)
#
#
# ### Number of participants
# 7Lists*30 subjects/list = 210

# %% [markdown]
# # Combine contexts with constrained db

# %%
# read in df with contexts
cntxts = pd.read_csv("swbd_contexts.csv")

# %%
cntxts = cntxts.drop(columns="FollowingContext")

# %%
# get the indixes from critical
crit_index = critical.Item_ID

# %% [markdown]
# ### Merge back in Wh colum
# so we can sample proportionately based on Wh

# %%
df_Wh = critical[["Item_ID","Wh","Question"]].rename(columns={"Item_ID": "TGrepID"})

# %%
# subset to the items that are just the ones filtered in the previos section

# otherwise, if using the database file with contexts directly in there, then this step
# is not necessary
df_valid = cntxts[cntxts["TGrepID"].isin(set(crit_index))]

# %%
# Merge
df_valid = df_valid.merge(df_Wh, how = 'inner', indicator=False)

# %%
df_valid.head()
# Out:
#     TGrepID  \
# 0  1049:139
# 1   1130:56
# 2   4531:36
# 3   6397:23
# 4   7981:19
#
#                                                                                                                                                                                                                          EntireSentence  \
# 0  i also thought about it, was of, uh, *-1 waiting *-2 to talk to you that, another thing that *t*-4 occurred to me is 0 there is not so much invasion of my privacy because i know how *-5 to behave *t*-6 such that there isn't *?*.
# 1                                                                                                                                                       and if that's gone, um, i, i really don't know how *-1 to live *t*-2 very well,
# ...

# %% [markdown]
# # Split EntireSentence on Question
# This is necessary because we need to bold the question only and not the Matrix in the experimental file

# %%
# split EntireSentence at the string that matches the value in the 'question' column
df_valid["Matrix"] = df_valid.apply(lambda x: x['EntireSentence'].replace(x['Question'],"").strip(),axis=1)

# %%
# split that last punctuation off, to be added back on in .js script
df_valid["punct"] = df_valid["Matrix"].apply(lambda x: list(x)[-1])

# %%
# remove that final punct from the Matrix column
df_valid["Matrix"] = df_valid["Matrix"].apply(lambda x: x.replace(list(x)[-1], ' '))

# %%
df_valid.head()
# Out:
#     TGrepID  \
# 0  1049:139
# 1   1130:56
# 2   4531:36
# 3   6397:23
# 4   7981:19
#
#                                                                                                                                                                                                                          EntireSentence  \
# 0  i also thought about it, was of, uh, *-1 waiting *-2 to talk to you that, another thing that *t*-4 occurred to me is 0 there is not so much invasion of my privacy because i know how *-5 to behave *t*-6 such that there isn't *?*.
# 1                                                                                                                                                       and if that's gone, um, i, i really don't know how *-1 to live *t*-2 very well,
# ...

# %% [markdown]
# # Generating random samples

# %% [markdown]
# ## First Iteration

# %% [markdown]
# 6 lists of 20, 1 of 15
#
# 15 how / 6 list
# 4 whats / 6 lists
# then random sample 1 item from the remainders
#
# last list is whatever's left over (total 15 items)

# %%
for n in range(1,8):
    how_sample = df_valid[df_valid["Wh"] == "how"].sample(15)
    df_valid = df_valid.drop(how_sample.index)    
    
    what_sample = df_valid[df_valid["Wh"] == "what"].sample(4)
    df_valid = df_valid.drop(what_sample.index)
    
    final_sample = df_valid[
        (df_valid["Wh"] != "how") &
        (df_valid["Wh"] != "what")
    ].sample(1)
    df_valid = df_valid.drop(final_sample.index)

    
    total = pd.concat([how_sample,what_sample,final_sample])
    # save to file
    filename = f"../../experiments/clean_corpus/01_experiment/corpus_{n}.txt".format(n=n)
    total.to_csv(filename,header=True,sep="\t",index=False)

# %% [markdown]
# ## Final Set
#
# List = 15
#
# 10 how

# %%
len(df_valid)
# Out:
# 15

# %% [markdown]
# ## Writing out should/could paraphrases

# %% [markdown]
# * Corpus_7

# %%
# df_valid.to_csv("../../experiments/clean_corpus/01_experiment/corpus_7.txt",header=True,sep="\t",index=False)

# %%
cc7 = pd.read_csv("../../experiments/clean_corpus/01_experiment/corpus_7.txt",sep="\t")

# %%
cc7.head(1)
# Out:
#     TGrepID                                  EntireSentence  \
# 0  13907:24  i think 0 it teaches kids how * to grow *t*-1.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  PreceedingContext  \
# ...

# %%
cc7["ShouldParaphrase"] = ""
cc7["CouldParaphrase"] = ""

# %%
cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "13907:24"] = cc7['ShouldParaphrase'].str.replace('', 'I think it teaches kids how they should grow.')
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "13907:24"] = cc7['CouldParaphrase'].str.replace('', 'I think it teaches kids how they could grow.')


cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "18673:73"] = cc7['ShouldParaphrase'].str.replace('', "We're trying to decide what we should put on one side of the house.")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "18673:73"] = cc7['CouldParaphrase'].str.replace('', "We're trying to decide what we could put on one side of the house.")

cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "42920:16"] = cc7['ShouldParaphrase'].str.replace('', "Well I know how I should use one.")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "42920:16"] = cc7['CouldParaphrase'].str.replace('', "Well I know how I could use one.")

cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "47381:11"] = cc7['ShouldParaphrase'].str.replace('', "Men know, right, how they should do that?")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "47381:11"] = cc7['CouldParaphrase'].str.replace('', "Men know, right, how they could do that?")


cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "58645:18"] = cc7['ShouldParaphrase'].str.replace('', "My dad wouldn't know what he should do.")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "58645:18"] = cc7['CouldParaphrase'].str.replace('', "My dad wouldn't know what he could do.")


cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "71650:16"] = cc7['ShouldParaphrase'].str.replace('', "You can't forget how you should ride a bike.")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "71650:16"] = cc7['CouldParaphrase'].str.replace('', "You can't forget how you could ride a bike.")



cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "71768:54"] = cc7['ShouldParaphrase'].str.replace('', "I mean they really know how they should isolate each of the different muscle groups, with those things.")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "71768:54"] = cc7['CouldParaphrase'].str.replace('', "I mean they really know how they could isolate each of the different muscle groups, with those things.")



cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "103781:16"] = cc7['ShouldParaphrase'].str.replace('', "I don't know how else I should explain.")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "103781:16"] = cc7['CouldParaphrase'].str.replace('', "I don't know how else I could explain.")


cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "105042:18"] = cc7['ShouldParaphrase'].str.replace('', "I remember learning how I should ski.")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "105042:18"] = cc7['CouldParaphrase'].str.replace('', "I remember learning how I could ski.")


cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "106081:42"] = cc7['ShouldParaphrase'].str.replace('', "What type of recommendations did you have when you decided where you should place him?")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "106081:42"] = cc7['CouldParaphrase'].str.replace('', "What type of recommendations did you have when you decided where you could place him?")

cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "109227:56"] = cc7['ShouldParaphrase'].str.replace('', "You need to get into the the system a little more and know where you should take things.")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "109227:56"] = cc7['CouldParaphrase'].str.replace('', "You need to get into the the system a little more and know where you could take things.")

cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "115523:46"] = cc7['ShouldParaphrase'].str.replace('', "When I like something, I usually try to figure out how I should make money off of it.")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "115523:46"] = cc7['CouldParaphrase'].str.replace('', "When I like something, I usually try to figure out how I could make money off of it.")

cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "118700:62"] = cc7['ShouldParaphrase'].str.replace('', "Half the time we don't know who we should support.")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "118700:62"] = cc7['CouldParaphrase'].str.replace('', "Half the time we don't know who we could support.")

cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "112241:25"] = cc7['ShouldParaphrase'].str.replace('', "My kids wanted to learn how they should play it.")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "112241:25"] = cc7['CouldParaphrase'].str.replace('', "My kids wanted to learn how they could play it.")

cc7['ShouldParaphrase'].loc[cc7["TGrepID"] == "172447:43"] = cc7['ShouldParaphrase'].str.replace('', "The old-timers, even the people who are technologists don't know how they should operate these electronic things, like VCR and what not.")
cc7['CouldParaphrase'].loc[cc7["TGrepID"] == "172447:43"] = cc7['CouldParaphrase'].str.replace('', "The old-timers, even the people who are technologists don't know how they could operate these electronic things, like VCR and what not.")

# %%
cc7
# Out:
#       TGrepID  \
# 0    13907:24
# 1    18673:73
# 2    42920:16
# 3    47381:11
# 4    58645:18
# 5    71650:16
# 6    71768:54
# 7   103781:16
# 8   105042:18
# 9   106081:42
# 10  109227:56
# 11  112241:25
# 12  115523:46
# 13  118700:62
# 14  172447:43
#
#                                                                                                                                         EntireSentence  \
# 0                                                                                                       i think 0 it teaches kids how * to grow *t*-1.
# 1                      and, you know, we're trying *-1 to decide what, what * to, what *-2 to put *t*-3 on one side of the house and things like that,
# 2                                                                                                                 well, i know how * to use one *t*-1.
# ...
